# %% [markdown]
# # VAR-2026 — 3DGS Baseline (Kaggle)
# Settings: **Internet = On**, **Accelerator = GPU T4 x2**.
# Sửa `DATA_ROOT` cho đúng slug dataset của bạn (chạy cell `ls` để xác nhận).

# %%
REPO_URL  = 'https://github.com/nhlich03/AI-Race-2026.git'
DATA_ROOT = '/kaggle/input/<ten-dataset>/VAI_NVS_DATA_ROUND2'   # thư mục chứa HCM0421/, bonsai/, ...
ITERS     = 7000   # 7000 = baseline nhanh; 30000 = full

# %%
# Xác nhận đường dẫn data trước (đôi khi Kaggle lồng thêm 1 cấp thư mục)
# !ls /kaggle/input/*/ && echo '---' && ls $DATA_ROOT

# %%
# !git clone $REPO_URL
# %cd AI-Race-2026
# !bash setup_kaggle.sh

# %%
# !python scripts/run_all.py \
    --gs_repo third_party/gaussian-splatting \
    --data_root $DATA_ROOT \
    --iterations $ITERS

# %%
# !python scripts/make_submission.py --submission submission --out /kaggle/working/submission_round1.zip
